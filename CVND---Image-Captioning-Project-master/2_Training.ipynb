# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:** The CNN-RNN architecture consists of a convolutional neural network (CNN) with 50 layer deep residual network obtained from TorchVision and a recurrent neural network (RNN) built with the long-short term memory (LSTM) cell. There is an embbeding layer that transforms the input caption tokens to the embedding dimension required by the RNN. The embedding feature size is 512. The LSTM cell has a hidden output size of 512. The output of the LSTM network goes through a dropout layer before being applied to a fully connected layer that yields the final prediction of the RNN. The choice of the hyperparameters was mainly influenced by the Show and tell paper (Vinyals, O. et.al., 2015), however the batch size chosen was based on the Show, attend and tell paper (Xu, K. et.al., 2015). Two LSTM layers with dropout were tested for the RNN, but seemed to perform worse than the single layer, hence the single layer RNN was retained.
#
#
# References:
#
# karpathy/char-rnn, 2018. [online] Available at: https://github.com/karpathy/char-rnn#tips-and-tricks.
#
# Vinyals, O., Toshev, A., Bengio, S. and Erhan, D., 2015. Show and tell: A neural image caption generator. In Proceedings of the IEEE conference on computer vision and pattern recognition (pp. 3156-3164).
#
# Xu, K., Ba, J., Kiros, R., Cho, K., Courville, A., Salakhudinov, R., Zemel, R. and Bengio, Y., 2015, June. Show, attend and tell: Neural image caption generation with visual attention. In International conference on machine learning (pp. 2048-2057).
#
# Zaremba, W., Sutskever, I. and Vinyals, O., 2014. Recurrent neural network regularization. arXiv preprint arXiv:1409.2329.
#
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:** The image tranform has been left at the default value because the normalisation it applies aligns with the CNN model chosen. In addition, the horizontal flip is a common feature of top image processing models on Kaggle, and has been retained.
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:** The trainable parameters selected for training are the weights in the embedding layer of the encoder and all trainable weights in the decoder. The pretrained weights in the encoder are not altered so as to preserve the tuning from its pretraining, also, using pretrained weights have been reported to reduce overfitting.
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:** The prefered optimizer is the ADAM algorithm because it leads to faster model convergence by updating the weights with exponentially weighted average of the gradients. This reduces the possibility of gradient descent slowing down at local minima.

# %%
# %load_ext autoreload
# %autoreload 2

import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math
import nltk
nltk.download('punkt')


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 64          # batch size
vocab_threshold = 5        # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 512           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 2             # number of training epochs
save_every = 1             # determines epoch frequency of saving model weights
print_every = 100          # determines batch window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size, batch_size=batch_size)


# encoder_file = 'encoder-1.pkl'
# decoder_file = 'decoder-1.pkl'

# # Load the trained weights.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))


# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.embed.parameters())

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params, lr=0.001)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=0.93s)
# creating index...
#   0%|          | 1037/414113 [00:00<01:25, 4810.53it/s]
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [01:07<00:00, 6112.75it/s]
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.torch/models/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:00<00:00, 112565463.16it/s]

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
response = requests.request("GET", 
                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                            headers={"Metadata-Flavor":"Google"})
sum_time = 0
for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        tic = int(round(time.time() * 1000))
        
        if time.time() - old_time > 60:
            old_time = time.time()
            requests.request("POST", 
                             "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                             headers={'Authorization': "STAR " + response.text})
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # zero the hidden state of the LSTM, this detaches it from its history
        decoder.hidden = decoder.init_hidden(batch_size)
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))  # Is it auto one-hot and logsoftmax for caption?
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
        
        toc = int(round(time.time() * 1000))
        batch_training_time_secs = ((toc - tic) / 1000)
        sum_time += batch_training_time_secs
        sum_time = int(sum_time)
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f, Time spent(secs): %d' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()), sum_time) 
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()  # clears output to re-write on same line?
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            sum_time = 0
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Epoch [1/2], Step [100/6471], Loss: 3.6337, Perplexity: 37.8514, Time spent(secs): 101
# Epoch [1/2], Step [200/6471], Loss: 3.5973, Perplexity: 36.4982, Time spent(secs): 100
# Epoch [1/2], Step [300/6471], Loss: 3.2267, Perplexity: 25.1956, Time spent(secs): 100
# Epoch [1/2], Step [400/6471], Loss: 3.0724, Perplexity: 21.5928, Time spent(secs): 100
# Epoch [1/2], Step [500/6471], Loss: 3.4452, Perplexity: 31.3497, Time spent(secs): 100
# Epoch [1/2], Step [600/6471], Loss: 3.4372, Perplexity: 31.1000, Time spent(secs): 100
# Epoch [1/2], Step [700/6471], Loss: 3.1592, Perplexity: 23.5515, Time spent(secs): 100
# Epoch [1/2], Step [800/6471], Loss: 2.9913, Perplexity: 19.9115, Time spent(secs): 100
# Epoch [1/2], Step [900/6471], Loss: 2.8676, Perplexity: 17.5944, Time spent(secs): 100
# Epoch [1/2], Step [1000/6471], Loss: 2.7721, Perplexity: 15.9915, Time spent(secs): 100
# Epoch [1/2], Step [1100/6471], Loss: 2.9852, Perplexity: 19.7909, Time spent(secs): 100
# Epoch [1/2], Step [1200/6471], Loss: 2.6084, Perplexity: 13.5777, Time spent(secs): 100
# Epoch [1/2], Step [1300/6471], Loss: 2.5666, Perplexity: 13.0214, Time spent(secs): 100
# Epoch [1/2], Step [1400/6471], Loss: 2.5958, Perplexity: 13.4077, Time spent(secs): 100
# Epoch [1/2], Step [1500/6471], Loss: 2.7072, Perplexity: 14.9871, Time spent(secs): 100
# Epoch [1/2], Step [1600/6471], Loss: 2.7255, Perplexity: 15.2644, Time spent(secs): 100
# Epoch [1/2], Step [1700/6471], Loss: 3.5425, Perplexity: 34.5525, Time spent(secs): 100
# Epoch [1/2], Step [1800/6471], Loss: 2.6460, Perplexity: 14.0979, Time spent(secs): 100
# Epoch [1/2], Step [1900/6471], Loss: 2.4088, Perplexity: 11.1204, Time spent(secs): 100
# Epoch [1/2], Step [2000/6471], Loss: 2.6438, Perplexity: 14.0659, Time spent(secs): 100
# Epoch [1/2], Step [2100/6471], Loss: 2.9163, Perplexity: 18.4737, Time spent(secs): 100
# Epoch [1/2], Step [2200/6471], Loss: 2.4951, Perplexity: 12.1229, Time spent(secs): 100
# Epoch [1/2], Step [2300/6471], Loss: 2.4651, Perplexity: 11.7642, Time spent(secs): 100
# Epoch [1/2], Step [2400/6471], Loss: 2.5229, Perplexity: 12.4641, Time spent(secs): 100
# Epoch [1/2], Step [2500/6471], Loss: 2.4643, Perplexity: 11.7549, Time spent(secs): 100
# Epoch [1/2], Step [2600/6471], Loss: 2.1888, Perplexity: 8.9242, Time spent(secs): 100
# Epoch [1/2], Step [2700/6471], Loss: 2.3261, Perplexity: 10.2377, Time spent(secs): 100
# Epoch [1/2], Step [2800/6471], Loss: 2.7887, Perplexity: 16.2594, Time spent(secs): 100
# Epoch [1/2], Step [2900/6471], Loss: 2.7945, Perplexity: 16.3543, Time spent(secs): 100
# Epoch [1/2], Step [3000/6471], Loss: 2.6131, Perplexity: 13.6413, Time spent(secs): 100
# Epoch [1/2], Step [3100/6471], Loss: 2.4341, Perplexity: 11.4056, Time spent(secs): 100
# Epoch [1/2], Step [3200/6471], Loss: 2.3483, Perplexity: 10.4676, Time spent(secs): 100
# Epoch [1/2], Step [3300/6471], Loss: 2.3722, Perplexity: 10.7210, Time spent(secs): 100
# Epoch [1/2], Step [3400/6471], Loss: 2.3253, Perplexity: 10.2296, Time spent(secs): 100
# Epoch [1/2], Step [3500/6471], Loss: 2.3009, Perplexity: 9.9829, Time spent(secs): 100
# Epoch [1/2], Step [3600/6471], Loss: 2.2976, Perplexity: 9.9504, Time spent(secs): 100
# Epoch [1/2], Step [3700/6471], Loss: 2.3624, Perplexity: 10.6167, Time spent(secs): 100
# Epoch [1/2], Step [3800/6471], Loss: 2.3176, Perplexity: 10.1516, Time spent(secs): 100
# Epoch [1/2], Step [3900/6471], Loss: 2.2606, Perplexity: 9.5885, Time spent(secs): 100
# Epoch [1/2], Step [4000/6471], Loss: 2.3559, Perplexity: 10.5481, Time spent(secs): 100
# Epoch [1/2], Step [4100/6471], Loss: 2.2481, Perplexity: 9.4696, Time spent(secs): 100
# Epoch [1/2], Step [4200/6471], Loss: 2.2801, Perplexity: 9.7773, Time spent(secs): 100
# Epoch [1/2], Step [4300/6471], Loss: 2.2733, Perplexity: 9.7116, Time spent(secs): 100
# Epoch [1/2], Step [4400/6471], Loss: 2.3111, Perplexity: 10.0855, Time spent(secs): 100
# Epoch [1/2], Step [4500/6471], Loss: 2.5039, Perplexity: 12.2297, Time spent(secs): 100
# Epoch [1/2], Step [4600/6471], Loss: 2.6142, Perplexity: 13.6566, Time spent(secs): 100
# Epoch [1/2], Step [4700/6471], Loss: 2.3580, Perplexity: 10.5698, Time spent(secs): 100
# Epoch [1/2], Step [4800/6471], Loss: 3.0009, Perplexity: 20.1028, Time spent(secs): 100
# Epoch [1/2], Step [4900/6471], Loss: 2.2376, Perplexity: 9.3709, Time spent(secs): 100
# Epoch [1/2], Step [5000/6471], Loss: 2.2682, Perplexity: 9.6616, Time spent(secs): 100
# Epoch [1/2], Step [5100/6471], Loss: 2.2243, Perplexity: 9.2471, Time spent(secs): 997
# Epoch [1/2], Step [5200/6471], Loss: 2.0842, Perplexity: 8.0382, Time spent(secs): 100
# Epoch [1/2], Step [5300/6471], Loss: 2.2582, Perplexity: 9.5662, Time spent(secs): 100
# Epoch [1/2], Step [5400/6471], Loss: 2.5279, Perplexity: 12.5266, Time spent(secs): 100
# Epoch [1/2], Step [5500/6471], Loss: 2.6616, Perplexity: 14.3186, Time spent(secs): 100
# Epoch [1/2], Step [5600/6471], Loss: 2.2480, Perplexity: 9.4691, Time spent(secs): 100
# Epoch [1/2], Step [5700/6471], Loss: 2.3034, Perplexity: 10.0083, Time spent(secs): 100
# Epoch [1/2], Step [5800/6471], Loss: 2.7512, Perplexity: 15.6613, Time spent(secs): 100
# Epoch [1/2], Step [5900/6471], Loss: 2.2028, Perplexity: 9.0503, Time spent(secs): 100
# Epoch [1/2], Step [6000/6471], Loss: 2.2386, Perplexity: 9.3800, Time spent(secs): 100
# Epoch [1/2], Step [6100/6471], Loss: 2.1386, Perplexity: 8.4873, Time spent(secs): 100
# Epoch [1/2], Step [6200/6471], Loss: 2.2767, Perplexity: 9.7447, Time spent(secs): 100
# Epoch [1/2], Step [6300/6471], Loss: 2.0983, Perplexity: 8.1523, Time spent(secs): 100
# Epoch [1/2], Step [6400/6471], Loss: 2.5783, Perplexity: 13.1748, Time spent(secs): 100
# Epoch [2/2], Step [100/6471], Loss: 2.2397, Perplexity: 9.3904, Time spent(secs): 1718
# Epoch [2/2], Step [200/6471], Loss: 2.2259, Perplexity: 9.2622, Time spent(secs): 100
# Epoch [2/2], Step [300/6471], Loss: 2.1375, Perplexity: 8.4783, Time spent(secs): 100
# Epoch [2/2], Step [400/6471], Loss: 1.9969, Perplexity: 7.3665, Time spent(secs): 100
# Epoch [2/2], Step [500/6471], Loss: 2.0780, Perplexity: 7.9884, Time spent(secs): 100
# Epoch [2/2], Step [600/6471], Loss: 2.5627, Perplexity: 12.9702, Time spent(secs): 100
# Epoch [2/2], Step [700/6471], Loss: 2.4818, Perplexity: 11.9627, Time spent(secs): 100
# Epoch [2/2], Step [800/6471], Loss: 2.0576, Perplexity: 7.8272, Time spent(secs): 100
# Epoch [2/2], Step [900/6471], Loss: 2.1214, Perplexity: 8.3425, Time spent(secs): 100
# Epoch [2/2], Step [1000/6471], Loss: 2.0625, Perplexity: 7.8657, Time spent(secs): 100
# Epoch [2/2], Step [1100/6471], Loss: 2.5374, Perplexity: 12.6468, Time spent(secs): 100
# Epoch [2/2], Step [1200/6471], Loss: 2.3223, Perplexity: 10.1993, Time spent(secs): 100
# Epoch [2/2], Step [1300/6471], Loss: 2.6171, Perplexity: 13.6955, Time spent(secs): 100
# Epoch [2/2], Step [1400/6471], Loss: 2.3938, Perplexity: 10.9546, Time spent(secs): 100
# Epoch [2/2], Step [1500/6471], Loss: 1.9820, Perplexity: 7.2576, Time spent(secs): 100
# Epoch [2/2], Step [1600/6471], Loss: 2.0638, Perplexity: 7.8756, Time spent(secs): 100
# Epoch [2/2], Step [1700/6471], Loss: 2.2162, Perplexity: 9.1722, Time spent(secs): 100
# Epoch [2/2], Step [1800/6471], Loss: 2.2021, Perplexity: 9.0441, Time spent(secs): 100
# Epoch [2/2], Step [1900/6471], Loss: 2.3920, Perplexity: 10.9350, Time spent(secs): 100
# Epoch [2/2], Step [2000/6471], Loss: 2.0520, Perplexity: 7.7834, Time spent(secs): 100
# Epoch [2/2], Step [2100/6471], Loss: 2.2576, Perplexity: 9.5601, Time spent(secs): 100
# Epoch [2/2], Step [2200/6471], Loss: 2.1002, Perplexity: 8.1677, Time spent(secs): 100
# Epoch [2/2], Step [2300/6471], Loss: 2.2761, Perplexity: 9.7385, Time spent(secs): 100
# Epoch [2/2], Step [2400/6471], Loss: 2.3133, Perplexity: 10.1073, Time spent(secs): 100
# Epoch [2/2], Step [2500/6471], Loss: 2.1185, Perplexity: 8.3184, Time spent(secs): 100
# Epoch [2/2], Step [2600/6471], Loss: 2.1174, Perplexity: 8.3098, Time spent(secs): 100
# Epoch [2/2], Step [2700/6471], Loss: 2.3709, Perplexity: 10.7069, Time spent(secs): 100
# Epoch [2/2], Step [2800/6471], Loss: 2.0624, Perplexity: 7.8648, Time spent(secs): 100
# Epoch [2/2], Step [2900/6471], Loss: 2.0447, Perplexity: 7.7270, Time spent(secs): 100
# Epoch [2/2], Step [3000/6471], Loss: 2.5891, Perplexity: 13.3182, Time spent(secs): 99
# Epoch [2/2], Step [3100/6471], Loss: 2.2243, Perplexity: 9.2471, Time spent(secs): 100
# Epoch [2/2], Step [3200/6471], Loss: 2.3008, Perplexity: 9.9822, Time spent(secs): 100
# Epoch [2/2], Step [3300/6471], Loss: 2.1015, Perplexity: 8.1784, Time spent(secs): 100
# Epoch [2/2], Step [3400/6471], Loss: 2.3024, Perplexity: 9.9985, Time spent(secs): 100
# Epoch [2/2], Step [3500/6471], Loss: 2.1034, Perplexity: 8.1939, Time spent(secs): 100
# Epoch [2/2], Step [3600/6471], Loss: 2.3205, Perplexity: 10.1804, Time spent(secs): 100
# Epoch [2/2], Step [3700/6471], Loss: 2.2403, Perplexity: 9.3960, Time spent(secs): 100
# Epoch [2/2], Step [3800/6471], Loss: 2.4882, Perplexity: 12.0397, Time spent(secs): 100
# Epoch [2/2], Step [3900/6471], Loss: 1.9989, Perplexity: 7.3810, Time spent(secs): 100
# Epoch [2/2], Step [4000/6471], Loss: 2.3048, Perplexity: 10.0223, Time spent(secs): 100
# Epoch [2/2], Step [4100/6471], Loss: 2.0095, Perplexity: 7.4595, Time spent(secs): 100
# Epoch [2/2], Step [4200/6471], Loss: 2.0551, Perplexity: 7.8080, Time spent(secs): 100
# Epoch [2/2], Step [4300/6471], Loss: 1.9635, Perplexity: 7.1240, Time spent(secs): 100
# Epoch [2/2], Step [4400/6471], Loss: 2.3727, Perplexity: 10.7266, Time spent(secs): 100
# Epoch [2/2], Step [4500/6471], Loss: 2.0038, Perplexity: 7.4174, Time spent(secs): 100
# Epoch [2/2], Step [4600/6471], Loss: 2.4898, Perplexity: 12.0587, Time spent(secs): 100
# Epoch [2/2], Step [4700/6471], Loss: 2.1515, Perplexity: 8.5977, Time spent(secs): 100
# Epoch [2/2], Step [4800/6471], Loss: 2.0257, Perplexity: 7.5811, Time spent(secs): 100
# Epoch [2/2], Step [4900/6471], Loss: 2.1437, Perplexity: 8.5311, Time spent(secs): 1007
# Epoch [2/2], Step [5000/6471], Loss: 2.1427, Perplexity: 8.5221, Time spent(secs): 100
# Epoch [2/2], Step [5100/6471], Loss: 2.2937, Perplexity: 9.9118, Time spent(secs): 100
# Epoch [2/2], Step [5200/6471], Loss: 2.4542, Perplexity: 11.6375, Time spent(secs): 100
# Epoch [2/2], Step [5300/6471], Loss: 2.2854, Perplexity: 9.8301, Time spent(secs): 995
# Epoch [2/2], Step [5400/6471], Loss: 2.1848, Perplexity: 8.8891, Time spent(secs): 100
# Epoch [2/2], Step [5500/6471], Loss: 2.0643, Perplexity: 7.8795, Time spent(secs): 100
# Epoch [2/2], Step [5600/6471], Loss: 2.0293, Perplexity: 7.6087, Time spent(secs): 100
# Epoch [2/2], Step [5700/6471], Loss: 2.1274, Perplexity: 8.3931, Time spent(secs): 100
# Epoch [2/2], Step [5800/6471], Loss: 2.2584, Perplexity: 9.5677, Time spent(secs): 100
# Epoch [2/2], Step [5900/6471], Loss: 2.0911, Perplexity: 8.0936, Time spent(secs): 100
# Epoch [2/2], Step [6000/6471], Loss: 2.0626, Perplexity: 7.8667, Time spent(secs): 100
# Epoch [2/2], Step [6100/6471], Loss: 2.6046, Perplexity: 13.5254, Time spent(secs): 100
# Epoch [2/2], Step [6200/6471], Loss: 2.2237, Perplexity: 9.2414, Time spent(secs): 100
# Epoch [2/2], Step [6300/6471], Loss: 2.2492, Perplexity: 9.4802, Time spent(secs): 100
# Epoch [2/2], Step [6400/6471], Loss: 2.1030, Perplexity: 8.1910, Time spent(secs): 100
# Epoch [2/2], Step [6471/6471], Loss: 2.2017, Perplexity: 9.0401, Time spent(secs): 710

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
